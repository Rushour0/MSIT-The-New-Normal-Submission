# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('hr.csv')
df=df[-3000:]
df.plot()
#plt.show()
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df2 = df[df.index %2 == 0]

# %%
df2
# Out:
#               date   time  heartRate
# 557586  2020-12-04  11:21         78
# 557588  2020-12-04  11:23         80
# 557590  2020-12-04  11:25         84
# 557592  2020-12-04  11:27         90
# 557594  2020-12-04  11:30        100
# ...            ...    ...        ...
# 560576  2020-12-06  23:51         94
# 560578  2020-12-06  23:53         89
# 560580  2020-12-06  23:55         84
# 560582  2020-12-06  23:57         73
# 560584  2020-12-06  23:59         74
#
# [1500 rows x 3 columns]

# %%
df3 = df2[df2.index %3 == 0]

# %%
plt.style.use('ggplot')

# %%
df3=df3[-400:]
df3
# Out:
#               date   time  heartRate
# 558186  2020-12-04  21:51         75
# 558192  2020-12-04  21:57         99
# 558198  2020-12-04  22:04        113
# 558204  2020-12-04  22:11         79
# 558210  2020-12-04  22:17         75
# ...            ...    ...        ...
# 560556  2020-12-06  23:31         91
# 560562  2020-12-06  23:37         76
# 560568  2020-12-06  23:43         94
# 560574  2020-12-06  23:49         98
# 560580  2020-12-06  23:55         84
#
# [400 rows x 3 columns]

# %%
plt.rcParams['figure.figsize'] = [20, 3]

# %%
df3.plot(color='red')
plt.fill_between(df3.index,df3.heartRate, color='#FC8F78')

# %%
len(df3)
# Out:
# 400
